# %% [markdown]
# # **Barycenters를 이용한 시계열 표준 패턴 추출**
#
# ### 창원대 전자공학과 20145234 황주효 (Hwang Ju-hyo, Department of Electronic Engineering, Changwon University)
# ---

# %%
import pickle
import matplotlib.pyplot as plt
import pandas as pd
from tslearn.clustering import TimeSeriesKMeans

with open("data.pickle","rb") as fr:
    X = pickle.load(fr)

km = TimeSeriesKMeans(n_clusters = 5, metric = 'dtw', max_iter = 50, n_init = 10, n_jobs = -1).fit(X)
Y = km.fit_predict(X)

# %%
fig, ax = plt.subplots(1, 5, figsize=(13, 5))
for yi in range(5):
    for xx in X[Y == yi]:
        ax[yi].plot(xx.ravel(), "k-", alpha=.2)
    ax[yi].plot(km.cluster_centers_[yi].ravel(), "r-")

# %% [markdown]
# * 5개 중 2번, 5번 클러스터의 데이터를 사용
# * 각 클러스터의 갯수를 세어본다

# %%
import numpy as np
np.unique(Y, return_counts = True)
# Out:
# (array([0, 1, 2, 3, 4], dtype=int64),
#  array([ 22, 257,  15,  89, 217], dtype=int64))

# %%
X_con = []
for i in [1,4]:
    X_con.append(pd.DataFrame(X[Y==i].reshape(X[Y==i].shape[0], 34)))

X_con = pd.concat(X_con)
X_con
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.025474  0.023627  0.036403  0.034556  0.034556  0.033632  0.033632
# 1    0.066379  0.068226  0.066379  0.067341  0.068226  0.067341  0.066379
# 2    0.053681  0.062762  0.064571  0.058221  0.066379  0.057336  0.057336
# 3    0.066379  0.067341  0.067341  0.066379  0.066379  0.067341  0.275715
# 4    0.055489  0.058221  0.057336  0.062762  0.058221  0.063686  0.283873
# ..        ...       ...       ...       ...       ...       ...       ...
# 212  0.026398  0.026398  0.054566  0.051872  0.051872  0.051872  0.052757
# 213  0.029091  0.028206  0.060030  0.060030  0.060915  0.060915  0.060030
# 214  0.020934  0.027283  0.055489  0.052757  0.061877  0.062762  0.060915
# 215  0.019972  0.019972  0.055489  0.052757  0.052757  0.052757  0.060915
# 216  0.025474  0.019972  0.052757  0.052757  0.050910  0.051872  0.050910
#
#            7         8         9   ...        24        25        26  \
# 0    0.033632  0.027283  0.032747  ...  0.024551  0.033632  0.035441
# 1    0.247470  0.259322  0.270251  ...  0.029091  0.075499  0.127371
# 2    0.072806  0.250202  0.264786  ...  0.080964  0.020934  0.095509
# 3    0.253858  0.261131  0.260246  ...  0.022742  0.088275  0.121022
# 4    0.247470  0.261131  0.261131  ...  0.019972  0.046408  0.114634
# ..        ...       ...       ...  ...       ...       ...       ...
# 212  0.052757  0.061877  0.053681  ...  0.031824  0.023627  0.104629
# 213  0.060030  0.059145  0.059145  ...  0.022742  0.025474  0.104629
# 214  0.060915  0.060030  0.058221  ...  0.019972  0.018163  0.098280
# 215  0.060030  0.060915  0.060915  ...  0.017278  0.019086  0.100089
# 216  0.051872  0.050910  0.051872  ...  0.023627  0.027283  0.109208
#
#            27        28        29        30        31        32        33
# 0    0.032747  0.035441  0.029091  0.036403  0.029977  0.029091  0.029977
# 1    0.531381  0.507754  0.494055  0.509524  0.517759  0.513180  0.023627
# 2    0.124678  0.498634  0.518644  0.514103  0.513180  0.513180  0.020934
# 3    0.522261  0.514103  0.520453  0.503175  0.513180  0.498634  0.027283
# 4    0.460423  0.505907  0.495863  0.509524  0.509524  0.524108  0.027283
# ..        ...       ...       ...       ...       ...       ...       ...
# 212  0.552315  0.514103  0.503175  0.524108  0.511333  0.519567  0.027283
# 213  0.491361  0.514988  0.503175  0.513180  0.512295  0.515912  0.024551
# 214  0.524108  0.505907  0.506792  0.515912  0.501328  0.019972  0.022742
# 215  0.484973  0.497710  0.496825  0.511333  0.511333  0.524993  0.033632
# 216  0.546850  0.510448  0.508639  0.520453  0.517759  0.517759  0.022742
#
# [474 rows x 34 columns]

# %%
X_re = np.array(X_con).reshape(X_con.shape[0], 34, 1)

from tslearn.barycenters import \
    euclidean_barycenter, \
    dtw_barycenter_averaging, \
    dtw_barycenter_averaging_subgradient, \
    softdtw_barycenter

def plot_helper(barycenter):
    # plot all points of the data set
    for series in X_re:
        plt.plot(series.ravel(), "k-", alpha=.2)
    # plot the given barycenter of them
    plt.plot(barycenter.ravel(), "r-", linewidth=2)

# %%
import time
for _tol in [0.1, 0.01, 0.001, 0.001]:
    for _iter in [1, 10, 100, 500]:

        start = time.time()
        plt.figure(figsize = (15, 5))
        ax1 = plt.subplot(1, 4, 1)
        plt.title("Euclidean barycenter")
        plot_helper(euclidean_barycenter(X_con))
        plt.text(0, 0.5, 'time : {}'.format(round(time.time() - start, 4)), fontsize = 15, )

        start = time.time()
        plt.subplot(1, 4, 2, sharex=ax1)
        plt.title("DBA (vectorized version of Petitjean's EM)")
        plot_helper(dtw_barycenter_averaging(X_con, max_iter=_iter, tol=_tol))
        plt.text(0, 0.6, 'iter : {}'.format(_iter), fontsize = 15, )
        plt.text(0, 0.5, 'time : {}'.format(round(time.time() - start, 4)), fontsize = 15, )
        plt.text(0, 0.4, 'tol : {}'.format(_tol), fontsize = 15, )

        start = time.time()
        plt.subplot(1, 4, 3, sharex=ax1)
        plt.title("DBA (subgradient descent approach)")
        plot_helper(dtw_barycenter_averaging_subgradient(X_con, max_iter=_iter, tol=_tol))
        plt.text(0, 0.6, 'iter : {}'.format(_iter), fontsize = 15, )
        plt.text(0, 0.5, 'time : {}'.format(round(time.time() - start, 4)), fontsize = 15, )
        plt.text(0, 0.4, 'tol : {}'.format(_tol), fontsize = 15, )

        start = time.time()
        plt.subplot(1, 4, 4, sharex=ax1)
        plt.title("Soft-DTW barycenter ($\gamma$=1.0)")
        plot_helper(softdtw_barycenter(X_con, gamma=1, max_iter=_iter, tol=_tol))
        plt.text(0, 0.6, 'iter : {}'.format(_iter), fontsize = 15, )
        plt.text(0, 0.5, 'time : {}'.format(round(time.time() - start, 4)), fontsize = 15, )
        plt.text(0, 0.4, 'tol : {}'.format(_tol), fontsize = 15, )

        # clip the axes for better readability

        # show the plot(s)
        plt.tight_layout()
        plt.show()
